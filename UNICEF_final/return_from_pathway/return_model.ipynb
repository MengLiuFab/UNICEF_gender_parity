# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
# check the missed countries.


data = pd.read_csv('UNICEF_percentage_and_population_levels_groups20220209.csv')

data = data[['country','Total_Never entered primary','Total_Dropped out of primary','Total_Still attending primary',
             'Total_Did not transition to lower secondary','Total_Dropped out of lower secondary','Total_Still attending lower secondary',
             'Total_Did not transition to upper secondary','Total_Transitioned to upper secondary',          
             'Total_population_agerange']]
data
# Out:
#         country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93     Viet Nam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange
# 0                               30.442579                   2777.983
# 1                               87.067217                    149.990
# 2                               51.285623                   1792.845
# 3                               14.700000                   2209.021
# 4                               59.300000                   2131.984
# ..                                    ...                        ...
# 92                              42.400000                    145.968
# 93                              74.300000                   3929.130
# 94                              31.000000                   1959.731
# 95                              25.788981                   1276.025
# 96                               6.577552                   1332.280
#
# [97 rows x 10 columns]

# %% [markdown]
# The UNICEF pathway data doesn't include the 'Dropped out of upper secondary'.
# The data is percentage data. We need to multiply the total population in the age range, Unit 1000.

# %% [markdown]
# These step-by-step subs make each levels only include the children that **specifically** leave at this level

# %% [markdown]
# # Sanity check for the mini group data
# 1. Primary - 33.86 + 8.254 + 3.1416 = 45.25
# 2. LS =  3.79 + 3.98 + 14.56 =22.33
# 3. US =  1.706868
#
# 45.531657	22.318897	1.706868
#
# The population is 16 to 18 as 952 + 926 + 900 = 2778

# %% [markdown]
# # Here we get the population data in needs, unit as one children

# %%
cats = data.columns.tolist()[1:-1]
print(cats)

for cat in cats:
    data[f'{cat}_pop'] = data[f'{cat}']/100 * data['Total_population_agerange'] * 1000
# percentage for 100, and 1000 as the unit for population 

pop_df = data 

pop_df 
 
# take out the dropout one, 
# same for upper secondary
# Out:
# ['Total_Never entered primary', 'Total_Dropped out of primary', 'Total_Still attending primary', 'Total_Did not transition to lower secondary', 'Total_Dropped out of lower secondary', 'Total_Still attending lower secondary', 'Total_Did not transition to upper secondary', 'Total_Transitioned to upper secondary']
#         country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93     Viet Nam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  \
# 0                               30.442579                   2777.983
# 1                               87.067217                    149.990
# 2                               51.285623                   1792.845
# 3                               14.700000                   2209.021
# 4                               59.300000                   2131.984
# ..                                    ...                        ...
# 92                              42.400000                    145.968
# 93                              74.300000                   3929.130
# 94                              31.000000                   1959.731
# 95                              25.788981                   1276.025
# 96                               6.577552                   1332.280
#
#     Total_Never entered primary_pop  Total_Dropped out of primary_pop  \
# 0                     940662.293496                     229310.741254
# 1                       1648.552290                       1070.629331
# 2                      38680.317844                      58303.808936
# 3                     170094.617000                     214275.037000
# 4                       4263.968000                      14923.888000
# ..                              ...                               ...
# 92                      2043.552000                       1897.584000
# 93                     66795.210000                      62866.080000
# 94                    211650.948000                     301798.574000
# 95                     44978.377455                     205783.971541
# 96                      4481.091366                      91339.887239
#
#     Total_Still attending primary_pop  \
# 0                        94888.643300
# 1                          148.738857
# 2                         7120.833048
# 3                       503656.788000
# 4                        31979.760000
# ..                                ...
# 92                        1167.744000
# 93                        3929.130000
# 94                      115624.129000
# 95                      166023.485148
# 96                        5631.746589
#
#     Total_Did not transition to lower secondary_pop  \
# 0                                     105183.949666
# 1                                        557.865393
# 2                                       7971.441581
# 3                                      35344.336000
# 4                                      29847.776000
# ..                                              ...
# 92                                      7006.464000
# 93                                     47149.560000
# 94                                    119543.591000
# 95                                     99237.374502
# 96                                    198168.288344
#
#     Total_Dropped out of lower secondary_pop  \
# 0                              110470.039840
# 1                                1092.956242
# 2                              230048.138658
# 3                               72897.693000
# 4                              130051.024000
# ..                                       ...
# 92                              15472.608000
# 93                             330046.920000
# 94                             109744.936000
# 95                              58752.962249
# 96                             236406.499874
#
#     Total_Still attending lower secondary_pop  \
# 0                               404361.164774
# 1                                   72.909191
# 2                               480804.872336
# 3                               872563.295000
# 4                               624671.312000
# ..                                        ...
# 92                               50650.896000
# 93                              192527.370000
# 94                              460536.785000
# 95                              302423.654225
# 96                              296767.672313
#
#     Total_Did not transition to upper secondary_pop  \
# 0                                      47416.496566
# 1                                      14806.229681
# 2                                      50443.852822
# 3                                      17672.168000
# 4                                      34111.744000
# ..                                              ...
# 92                                      5838.720000
# 93                                    310401.270000
# 94                                     33315.427000
# 95                                     69751.324831
# 96                                    411853.403237
#
#     Total_Transitioned to upper secondary_pop
# 0                                8.456897e+05
# 1                                1.305921e+05
# 2                                9.194717e+05
# 3                                3.247261e+05
# 4                                1.264267e+06
# ..                                        ...
# 92                               6.189043e+04
# 93                               2.919344e+06
# 94                               6.075166e+05
# 95                               3.290739e+05
# 96                               8.763141e+04
#
# [97 rows x 18 columns]

# %% [markdown]
# 2778000 * 0.3386  = 940 630

# %%
# check the negative case
(pop_df.iloc[:,1:] < 0).any()
# Out:
# Total_Never entered primary                        False
# Total_Dropped out of primary                       False
# Total_Still attending primary                      False
# Total_Did not transition to lower secondary        False
# Total_Dropped out of lower secondary               False
# Total_Still attending lower secondary              False
# Total_Did not transition to upper secondary        False
# Total_Transitioned to upper secondary              False
# Total_population_agerange                          False
# Total_Never entered primary_pop                    False
# Total_Dropped out of primary_pop                   False
# Total_Still attending primary_pop                  False
# Total_Did not transition to lower secondary_pop    False
# Total_Dropped out of lower secondary_pop           False
# Total_Still attending lower secondary_pop          False
# Total_Did not transition to upper secondary_pop    False
# Total_Transitioned to upper secondary_pop          False
# dtype: bool

# %% [markdown]
# # here is the duration of education for each level

# %%
dur_data = pd.read_csv('years_of_school_levels.csv') 
ind_list = ['Theoretical duration of primary education (years)','Theoretical duration of lower secondary education (years)','Theoretical duration of upper secondary education (years)']
bool_list = dur_data.Indicator.isin(ind_list)
dur_data = dur_data[bool_list]


levels = ['primary','lower secondary','upper secondary']
for level in levels:
    
    dur_group_tmp = dur_data[['Country','Indicator','Time']]
    dur_group_tmp = dur_group_tmp[dur_group_tmp['Indicator']==f'Theoretical duration of {level} education (years)']
    
    
    dur_group = dur_group_tmp.groupby('Country').max(numeric_only=False)
    
    if level == 'primary': 
        dur_df = dur_group.reset_index()
        dur_df = dur_df.merge(dur_data,on=['Country','Time','Indicator'])
        dur_df=dur_df[['Country','Value']]
        dur_df=dur_df.rename({'Value':f'{level}_dur'},axis='columns')
    else:
        dur_df_tmp = dur_group.reset_index()
        dur_df_tmp = dur_df_tmp.merge(dur_data,on=['Country','Time','Indicator'])
        dur_df_tmp = dur_df_tmp[['Country','Value']]
        dur_df_tmp=dur_df_tmp.rename({'Value':f'{level}_dur'},axis='columns')
        dur_df = dur_df.merge(dur_df_tmp,on='Country')
dur_df
# dur_df['primary_need_dur'] = dur_df['primary_dur'] + dur_df['lower secondary_dur'] +dur_df['upper secondary_dur'] 
# dur_df['lower secondary_need_dur'] =  dur_df['lower secondary_dur'] +dur_df['upper secondary_dur'] 
# dur_df['upper secondary_need_dur'] =  dur_df['upper secondary_dur'] 
# dur_df['drop_primary_need_dur'] = dur_df['primary_dur']/2 + dur_df['lower secondary_dur'] +dur_df['upper secondary_dur'] 
# dur_df['drop_lower secondary_need_dur'] = dur_df['lower secondary_dur']/2 +dur_df['upper secondary_dur'] 
# # use the demical half year 
# dur_df
# Out:
#             Country  primary_dur  lower secondary_dur  upper secondary_dur
# 0       Afghanistan          6.0                  3.0                  3.0
# 1           Albania          5.0                  4.0                  3.0
# 2           Algeria          5.0                  4.0                  3.0
# 3    American Samoa          6.0                  4.0                  2.0
# 4           Andorra          6.0                  4.0                  2.0
# ..              ...          ...                  ...                  ...
# 219        Viet Nam          5.0                  4.0                  3.0
# 220  Western Sahara          5.0                  3.0                  3.0
# 221           Yemen          6.0                  3.0                  3.0
# 222          Zambia          7.0                  2.0                  3.0
# 223        Zimbabwe          7.0                  2.0                  4.0
#
# [224 rows x 4 columns]

# %% [markdown]
# # combine the duration data and filled the default

# %%
pop_df.rename({
    'country':'Country'
},axis=1,inplace=True)
main_df = pop_df.merge(dur_df,how='left',on='Country')
display(main_df)

main_df['primary_dur'] = main_df['primary_dur'].fillna(6)
main_df['lower secondary_dur'] = main_df['lower secondary_dur'].fillna(3)
main_df['upper secondary_dur'] = main_df['upper secondary_dur'].fillna(3)
# Out:
#         Country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93     Viet Nam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                               30.442579                   2777.983  ...
# 1                               87.067217                    149.990  ...
# 2                               51.285623                   1792.845  ...
# 3                               14.700000                   2209.021  ...
# 4                               59.300000                   2131.984  ...
# ..                                    ...                        ...  ...
# 92                              42.400000                    145.968  ...
# 93                              74.300000                   3929.130  ...
# 94                              31.000000                   1959.731  ...
# 95                              25.788981                   1276.025  ...
# 96                               6.577552                   1332.280  ...
#
#     Total_Dropped out of primary_pop  Total_Still attending primary_pop  \
# 0                      229310.741254                       94888.643300
# 1                        1070.629331                         148.738857
# 2                       58303.808936                        7120.833048
# 3                      214275.037000                      503656.788000
# 4                       14923.888000                       31979.760000
# ..                               ...                                ...
# 92                       1897.584000                        1167.744000
# 93                      62866.080000                        3929.130000
# 94                     301798.574000                      115624.129000
# 95                     205783.971541                      166023.485148
# 96                      91339.887239                        5631.746589
#
#     Total_Did not transition to lower secondary_pop  \
# 0                                     105183.949666
# 1                                        557.865393
# 2                                       7971.441581
# 3                                      35344.336000
# 4                                      29847.776000
# ..                                              ...
# 92                                      7006.464000
# 93                                     47149.560000
# 94                                    119543.591000
# 95                                     99237.374502
# 96                                    198168.288344
#
#     Total_Dropped out of lower secondary_pop  \
# 0                              110470.039840
# 1                                1092.956242
# 2                              230048.138658
# 3                               72897.693000
# 4                              130051.024000
# ..                                       ...
# 92                              15472.608000
# 93                             330046.920000
# 94                             109744.936000
# 95                              58752.962249
# 96                             236406.499874
#
#     Total_Still attending lower secondary_pop  \
# 0                               404361.164774
# 1                                   72.909191
# 2                               480804.872336
# 3                               872563.295000
# 4                               624671.312000
# ..                                        ...
# 92                               50650.896000
# 93                              192527.370000
# 94                              460536.785000
# 95                              302423.654225
# 96                              296767.672313
#
#     Total_Did not transition to upper secondary_pop  \
# 0                                      47416.496566
# 1                                      14806.229681
# 2                                      50443.852822
# 3                                      17672.168000
# 4                                      34111.744000
# ..                                              ...
# 92                                      5838.720000
# 93                                    310401.270000
# 94                                     33315.427000
# 95                                     69751.324831
# 96                                    411853.403237
#
#     Total_Transitioned to upper secondary_pop  primary_dur  \
# 0                                8.456897e+05          6.0
# 1                                1.305921e+05          5.0
# 2                                9.194717e+05          5.0
# 3                                3.247261e+05          6.0
# 4                                1.264267e+06          6.0
# ..                                        ...          ...
# 92                               6.189043e+04          6.0
# 93                               2.919344e+06          5.0
# 94                               6.075166e+05          6.0
# 95                               3.290739e+05          7.0
# 96                               8.763141e+04          7.0
#
#     lower secondary_dur  upper secondary_dur
# 0                   3.0                  3.0
# 1                   4.0                  3.0
# 2                   4.0                  3.0
# 3                   3.0                  3.0
# 4                   3.0                  3.0
# ..                  ...                  ...
# 92                  3.0                  3.0
# 93                  4.0                  3.0
# 94                  3.0                  3.0
# 95                  2.0                  3.0
# 96                  2.0                  4.0
#
# [97 rows x 21 columns]

# %% [markdown]
# The drop out of school children need *half* of current session and all session later. The children-in-need need all the year from now on.

# %% [markdown]
# # Currently, not GINI data, but remember to time 50% discount for the GDP earning.

# %% [markdown]
# # load the GDP values, Units are Dollar per Capita

# %%
gdp_data = pd.read_csv('GDP_percapital_UIS.csv') 

gpd_data_value = gdp_data.iloc[:,4:].T
gpd_data_value=gpd_data_value.dropna(axis=1,how='all')
gdp_data['GDP']=gpd_data_value.apply(lambda x: x[x.notnull()].values[-1]).T
gdp_df = gdp_data[['Country Name','GDP']]
gdp_df
# Out:
#                     Country Name           GDP
# 0                          Aruba  30253.279360
# 1    Africa Eastern and Southern   1356.699267
# 2                    Afghanistan    516.747871
# 3     Africa Western and Central   1710.073363
# 4                         Angola   1776.166868
# ..                           ...           ...
# 261                       Kosovo   4346.637931
# 262                  Yemen, Rep.    758.145242
# 263                 South Africa   5655.867654
# 264                       Zambia    985.132436
# 265                     Zimbabwe   1214.509820
#
# [266 rows x 2 columns]

# %% [markdown]
# # The return rates are the increase of salery **from previous year** for the two levels.
# From the paper

# %%
return_data = pd.read_excel('Comparable Returns to Education Database.xlsx',sheet_name= 'Returns Database') 
maxyear = return_data.groupby(['Economy'],sort=False)['Year'].max()
return_data = return_data[['Economy','Year','Pri','Sec',' β1']]
return_data = return_data.merge(maxyear,on=['Economy','Year'])
# if the secondary data is empty, fill with same as the primary
return_data['Sec'].fillna(return_data[' β1'],inplace=True)
return_data = return_data[['Economy','Year','Pri','Sec']]
return_data.rename({'Pri':'primary_return_rate','Sec':'secondary_return_rate'},axis='columns',inplace=True)
return_df = return_data.dropna()
return_df
# Out:
#                 Economy  Year  primary_return_rate  secondary_return_rate
# 0           Afghanistan  2007             4.110700               1.552420
# 1               Albania  2005            14.555667               2.877140
# 2             Argentina  2012             3.715300               4.690300
# 3               Armenia  2008            39.688335               0.829500
# 4             Australia  2010            13.997901              20.267717
# ..                  ...   ...                  ...                    ...
# 136  West Bank and Gaza  2008             8.101767               0.002800
# 138        South Africa  2011             8.879499              12.272751
# 139    Congo, Dem. Rep.  2004             8.990500               1.689300
# 140              Zambia  2012            13.316266              12.065867
# 141            Zimbabwe  2007            48.733002              17.451998
#
# [93 rows x 4 columns]

# %% [markdown]
# # adding the GDP data

# %%
replace_gdp={'Egypt, Arab Rep.':'Egypt','Congo, Dem. Rep.':'Democratic Republic of the Congo',
             'Congo, Rep.':'Congo',
             'Lao PDR':'Lao People\'s Democratic Republic',
             'St. Lucia':'Saint Lucia',
             'Yemen, Rep.' : 'Yemen'
             }

replace_pop={'C√¥te d\'Ivoire':'Cote d\'Ivoire',
             'Viet Nam':'Vietnam'}
gdp_df = gdp_df.rename({'Country Name':'Country'},axis='columns')
gdp_df = gdp_df.replace(replace_gdp)
main_df = main_df.replace(replace_pop)
main_df = main_df.merge(gdp_df,on='Country',how='left')
main_df
# Out:
#         Country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93      Vietnam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                               30.442579                   2777.983  ...
# 1                               87.067217                    149.990  ...
# 2                               51.285623                   1792.845  ...
# 3                               14.700000                   2209.021  ...
# 4                               59.300000                   2131.984  ...
# ..                                    ...                        ...  ...
# 92                              42.400000                    145.968  ...
# 93                              74.300000                   3929.130  ...
# 94                              31.000000                   1959.731  ...
# 95                              25.788981                   1276.025  ...
# 96                               6.577552                   1332.280  ...
#
#     Total_Still attending primary_pop  \
# 0                        94888.643300
# 1                          148.738857
# 2                         7120.833048
# 3                       503656.788000
# 4                        31979.760000
# ..                                ...
# 92                        1167.744000
# 93                        3929.130000
# 94                      115624.129000
# 95                      166023.485148
# 96                        5631.746589
#
#     Total_Did not transition to lower secondary_pop  \
# 0                                     105183.949666
# 1                                        557.865393
# 2                                       7971.441581
# 3                                      35344.336000
# 4                                      29847.776000
# ..                                              ...
# 92                                      7006.464000
# 93                                     47149.560000
# 94                                    119543.591000
# 95                                     99237.374502
# 96                                    198168.288344
#
#     Total_Dropped out of lower secondary_pop  \
# 0                              110470.039840
# 1                                1092.956242
# 2                              230048.138658
# 3                               72897.693000
# 4                              130051.024000
# ..                                       ...
# 92                              15472.608000
# 93                             330046.920000
# 94                             109744.936000
# 95                              58752.962249
# 96                             236406.499874
#
#     Total_Still attending lower secondary_pop  \
# 0                               404361.164774
# 1                                   72.909191
# 2                               480804.872336
# 3                               872563.295000
# 4                               624671.312000
# ..                                        ...
# 92                               50650.896000
# 93                              192527.370000
# 94                              460536.785000
# 95                              302423.654225
# 96                              296767.672313
#
#     Total_Did not transition to upper secondary_pop  \
# 0                                      47416.496566
# 1                                      14806.229681
# 2                                      50443.852822
# 3                                      17672.168000
# 4                                      34111.744000
# ..                                              ...
# 92                                      5838.720000
# 93                                    310401.270000
# 94                                     33315.427000
# 95                                     69751.324831
# 96                                    411853.403237
#
#     Total_Transitioned to upper secondary_pop  primary_dur  \
# 0                                8.456897e+05          6.0
# 1                                1.305921e+05          5.0
# 2                                9.194717e+05          5.0
# 3                                3.247261e+05          6.0
# 4                                1.264267e+06          6.0
# ..                                        ...          ...
# 92                               6.189043e+04          6.0
# 93                               2.919344e+06          5.0
# 94                               6.075166e+05          6.0
# 95                               3.290739e+05          7.0
# 96                               8.763141e+04          7.0
#
#     lower secondary_dur  upper secondary_dur           GDP
# 0                   3.0                  3.0    516.747871
# 1                   4.0                  3.0   5246.292306
# 2                   4.0                  3.0   3306.858208
# 3                   3.0                  3.0   1776.166868
# 4                   3.0                  3.0   8579.017773
# ..                  ...                  ...           ...
# 92                  3.0                  3.0  15438.411670
# 93                  4.0                  3.0   2785.724161
# 94                  3.0                  3.0    758.145242
# 95                  2.0                  3.0    985.132436
# 96                  2.0                  4.0   1214.509820
#
# [97 rows x 22 columns]

# %% [markdown]
# # Adding the return data.
# default inrease rate is 10%

# %%
return_df = return_df.rename({'Economy':'Country'},axis = 1)
data_final=main_df.merge(return_df,on='Country',how='left')
data_final['primary_return_rate'] = data_final['primary_return_rate'].fillna(10.0)
data_final['secondary_return_rate'] = data_final['secondary_return_rate'].fillna(10.0)
data_final
# Out:
#         Country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93      Vietnam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                               30.442579                   2777.983  ...
# 1                               87.067217                    149.990  ...
# 2                               51.285623                   1792.845  ...
# 3                               14.700000                   2209.021  ...
# 4                               59.300000                   2131.984  ...
# ..                                    ...                        ...  ...
# 92                              42.400000                    145.968  ...
# 93                              74.300000                   3929.130  ...
# 94                              31.000000                   1959.731  ...
# 95                              25.788981                   1276.025  ...
# 96                               6.577552                   1332.280  ...
#
#     Total_Still attending lower secondary_pop  \
# 0                               404361.164774
# 1                                   72.909191
# 2                               480804.872336
# 3                               872563.295000
# 4                               624671.312000
# ..                                        ...
# 92                               50650.896000
# 93                              192527.370000
# 94                              460536.785000
# 95                              302423.654225
# 96                              296767.672313
#
#     Total_Did not transition to upper secondary_pop  \
# 0                                      47416.496566
# 1                                      14806.229681
# 2                                      50443.852822
# 3                                      17672.168000
# 4                                      34111.744000
# ..                                              ...
# 92                                      5838.720000
# 93                                    310401.270000
# 94                                     33315.427000
# 95                                     69751.324831
# 96                                    411853.403237
#
#     Total_Transitioned to upper secondary_pop  primary_dur  \
# 0                                8.456897e+05          6.0
# 1                                1.305921e+05          5.0
# 2                                9.194717e+05          5.0
# 3                                3.247261e+05          6.0
# 4                                1.264267e+06          6.0
# ..                                        ...          ...
# 92                               6.189043e+04          6.0
# 93                               2.919344e+06          5.0
# 94                               6.075166e+05          6.0
# 95                               3.290739e+05          7.0
# 96                               8.763141e+04          7.0
#
#     lower secondary_dur  upper secondary_dur           GDP    Year  \
# 0                   3.0                  3.0    516.747871  2007.0
# 1                   4.0                  3.0   5246.292306  2005.0
# 2                   4.0                  3.0   3306.858208     NaN
# 3                   3.0                  3.0   1776.166868     NaN
# 4                   3.0                  3.0   8579.017773  2012.0
# ..                  ...                  ...           ...     ...
# 92                  3.0                  3.0  15438.411670  2012.0
# 93                  4.0                  3.0   2785.724161  2010.0
# 94                  3.0                  3.0    758.145242     NaN
# 95                  2.0                  3.0    985.132436  2012.0
# 96                  2.0                  4.0   1214.509820  2007.0
#
#     primary_return_rate  secondary_return_rate
# 0              4.110700               1.552420
# 1             14.555667               2.877140
# 2             10.000000              10.000000
# 3             10.000000              10.000000
# 4              3.715300               4.690300
# ..                  ...                    ...
# 92             3.993366               4.777500
# 93             8.305800               3.264600
# 94            10.000000              10.000000
# 95            13.316266              12.065867
# 96            48.733002              17.451998
#
# [97 rows x 25 columns]

# %%
data_final['increasemental_rate_of_salaries_Never_entered_primary']  = (
                                    ((data_final['primary_return_rate']/100)+1)**data_final['primary_dur'] 
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['lower secondary_dur']
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['upper secondary_dur']
                                      * 100)

data_final['increasemental_rate_of_Dropped_out_of_primary']  = (
                                    ((data_final['primary_return_rate']/100)+1)**(data_final['primary_dur']/2)
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['lower secondary_dur']
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['upper secondary_dur']
                                      * 100)

data_final['increasemental_rate_of_Still_in_primary']  = (
                                    ((data_final['primary_return_rate']/100)+1)**(data_final['primary_dur']/2)
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['lower secondary_dur']
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['upper secondary_dur']
                                      * 100)

data_final['increasemental_rate_of_salaries_Did_not_transition_to_lower_secondary']  =  (
                                    ((data_final['secondary_return_rate']/100)+1)**data_final['lower secondary_dur']
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['upper secondary_dur']
                                      * 100)

data_final['increasemental_rate_of_salaries_Dropped_out_of_lower_secondary']  =  (
                                    ((data_final['secondary_return_rate']/100)+1)**(data_final['lower secondary_dur']/2)
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['upper secondary_dur']
                                      * 100)

data_final['increasemental_rate_of_salaries_Still_in_lower_secondary']  =  (
                                    ((data_final['secondary_return_rate']/100)+1)**(data_final['lower secondary_dur']/2)
                                      *((data_final['secondary_return_rate']/100)+1)**data_final['upper secondary_dur']
                                      * 100)


data_final['increasemental_rate_of_Did_not_transition_to_upper_secondary']  = (
                                      ((data_final['secondary_return_rate']/100)+1)**data_final['upper secondary_dur']
                                      * 100)
data_final
# Out:
#         Country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93      Vietnam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                               30.442579                   2777.983  ...
# 1                               87.067217                    149.990  ...
# 2                               51.285623                   1792.845  ...
# 3                               14.700000                   2209.021  ...
# 4                               59.300000                   2131.984  ...
# ..                                    ...                        ...  ...
# 92                              42.400000                    145.968  ...
# 93                              74.300000                   3929.130  ...
# 94                              31.000000                   1959.731  ...
# 95                              25.788981                   1276.025  ...
# 96                               6.577552                   1332.280  ...
#
#       Year  primary_return_rate  secondary_return_rate  \
# 0   2007.0             4.110700               1.552420
# 1   2005.0            14.555667               2.877140
# 2      NaN            10.000000              10.000000
# 3      NaN            10.000000              10.000000
# 4   2012.0             3.715300               4.690300
# ..     ...                  ...                    ...
# 92  2012.0             3.993366               4.777500
# 93  2010.0             8.305800               3.264600
# 94     NaN            10.000000              10.000000
# 95  2012.0            13.316266              12.065867
# 96  2007.0            48.733002              17.451998
#
#     increasemental_rate_of_salaries_Never_entered_primary  \
# 0                                          139.673452
# 1                                          240.610773
# 2                                          313.842838
# 3                                          313.842838
# 4                                          163.868557
# ..                                                ...
# 92                                         167.356282
# 93                                         186.603099
# 94                                         313.842838
# 95                                         424.045612
# 96                                        4226.820929
#
#     increasemental_rate_of_Dropped_out_of_primary  \
# 0                                      123.773526
# 1                                      171.306413
# 2                                      247.303640
# 3                                      235.794769
# 4                                      146.881516
# ..                                            ...
# 92                                     148.807598
# 93                                     152.858489
# 94                                     235.794769
# 95                                     273.772410
# 96                                    1053.387472
#
#     increasemental_rate_of_Still_in_primary  \
# 0                                123.773526
# 1                                171.306413
# 2                                247.303640
# 3                                235.794769
# 4                                146.881516
# ..                                      ...
# 92                               148.807598
# 93                               152.858489
# 94                               235.794769
# 95                               273.772410
# 96                              1053.387472
#
#     increasemental_rate_of_salaries_Did_not_transition_to_lower_secondary  \
# 0                                          109.683592
# 1                                          121.964146
# 2                                          194.871710
# 3                                          177.156100
# 4                                          131.655397
# ..                                                ...
# 92                                         132.314730
# 93                                         125.216128
# 94                                         177.156100
# 95                                         176.752997
# 96                                         262.520032
#
#     increasemental_rate_of_salaries_Dropped_out_of_lower_secondary  \
# 0                                          107.178148
# 1                                          115.237655
# 2                                          161.051000
# 3                                          153.556103
# 4                                          122.907674
# ..                                                ...
# 92                                         123.369029
# 93                                         117.424126
# 94                                         153.556103
# 95                                         157.722419
# 96                                         223.512616
#
#     increasemental_rate_of_salaries_Still_in_lower_secondary  \
# 0                                          107.178148
# 1                                          115.237655
# 2                                          161.051000
# 3                                          153.556103
# 4                                          122.907674
# ..                                                ...
# 92                                         123.369029
# 93                                         117.424126
# 94                                         153.556103
# 95                                         157.722419
# 96                                         223.512616
#
#     increasemental_rate_of_Did_not_transition_to_upper_secondary
# 0                                          104.729934
# 1                                          108.882140
# 2                                          133.100000
# 3                                          133.100000
# 4                                          114.741186
# ..                                                ...
# 92                                         115.028140
# 93                                         110.117008
# 94                                         133.100000
# 95                                         140.740818
# 96                                         190.301246
#
# [97 rows x 32 columns]

# %%
##  around the year before into inter 
##  experience discount  
def retrun_rate_long_term(return_rate,year_before_work,year_of_work=40,discount_rate=10):
    year_before_work = np.ceil(year_before_work)
    return_sum = 0 
    for year in range(int(year_before_work),int(year_before_work)+int(year_of_work)):
        return_this_year = (1+return_rate/100)/(1+(discount_rate/100))**year
        return_sum = return_sum + return_this_year
    return return_sum

# %%
data_final['year_before_work_primary_full'] = data_final['primary_dur'] + data_final['lower secondary_dur'] + data_final['upper secondary_dur']
data_final['year_before_work_primary_half'] = data_final['primary_dur']/2 + data_final['lower secondary_dur'] + data_final['upper secondary_dur']
data_final['year_before_work_LS_full'] =  data_final['lower secondary_dur'] + data_final['upper secondary_dur']
data_final['year_before_work_LS_half'] =  data_final['lower secondary_dur']/2 + data_final['upper secondary_dur']
data_final['year_before_work_US_full'] = data_final['upper secondary_dur']

# %%
f = retrun_rate_long_term


data_final['increasemental_rate_of_salaries_Never_entered_primary_longterm'] = data_final.apply(lambda x: f(x['increasemental_rate_of_salaries_Never_entered_primary'], x['year_before_work_primary_full']), axis=1) 
data_final['increasemental_rate_of_salaries_Dropped_out_of_primary_longterm']  = data_final.apply(lambda x: f(x['increasemental_rate_of_Dropped_out_of_primary'], x['year_before_work_primary_half']), axis=1)                                                                                                            
data_final['increasemental_rate_of_salaries_Still_attending_primary_longterm'] =  data_final.apply(lambda x: f(x['increasemental_rate_of_Still_in_primary'], x['year_before_work_primary_half']), axis=1)                                                                                            

data_final['increasemental_rate_of_salaries_Did_not_transition_to_lower_secondary_longterm'] = data_final.apply(lambda x: f(x['increasemental_rate_of_salaries_Did_not_transition_to_lower_secondary'], x['year_before_work_LS_full']), axis=1) 
data_final['increasemental_rate_of_salaries_Dropped_out_of_lower_secondary_longterm'] = data_final.apply(lambda x: f(x['increasemental_rate_of_salaries_Dropped_out_of_lower_secondary'], x['year_before_work_LS_half']), axis=1) 
data_final['increasemental_rate_of_salaries_Still_attending_lower_secondary_longterm'] = data_final.apply(lambda x: f(x['increasemental_rate_of_salaries_Still_in_lower_secondary'], x['year_before_work_LS_half']), axis=1) 
data_final['increasemental_rate_of_salaries_Did_not_transition_to_upper_secondary_longterm'] = data_final.apply(lambda x: f(x['increasemental_rate_of_Did_not_transition_to_upper_secondary'], x['year_before_work_US_full']), axis=1)

# %%
item_to_cal = ['Total_Never entered primary','Total_Dropped out of primary','Total_Still attending primary',
             'Total_Did not transition to lower secondary','Total_Dropped out of lower secondary','Total_Still attending lower secondary',
             'Total_Did not transition to upper secondary']

for item in item_to_cal:
    item_tmp = item[6:]
    item_tmp = item_tmp.replace(" ","_")
    data_final[f"{item}_return_in_money"] = data_final[f'increasemental_rate_of_salaries_{item_tmp}_longterm'] * data_final['GDP'] * 0.5 * data_final[f'{item}_pop']
data_final
# Out:
#         Country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93      Vietnam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                               30.442579                   2777.983  ...
# 1                               87.067217                    149.990  ...
# 2                               51.285623                   1792.845  ...
# 3                               14.700000                   2209.021  ...
# 4                               59.300000                   2131.984  ...
# ..                                    ...                        ...  ...
# 92                              42.400000                    145.968  ...
# 93                              74.300000                   3929.130  ...
# 94                              31.000000                   1959.731  ...
# 95                              25.788981                   1276.025  ...
# 96                               6.577552                   1332.280  ...
#
#     increasemental_rate_of_salaries_Dropped_out_of_lower_secondary_longterm  \
# 0                                           13.837891
# 1                                           14.376203
# 2                                           17.436179
# 3                                           16.935578
# 4                                           14.888501
# ..                                                ...
# 92                                          14.919316
# 93                                          14.522243
# 94                                          16.935578
# 95                                          18.935241
# 96                                          21.608130
#
#     increasemental_rate_of_salaries_Still_attending_lower_secondary_longterm  \
# 0                                           13.837891
# 1                                           14.376203
# 2                                           17.436179
# 3                                           16.935578
# 4                                           14.888501
# ..                                                ...
# 92                                          14.919316
# 93                                          14.522243
# 94                                          16.935578
# 95                                          18.935241
# 96                                          21.608130
#
#     increasemental_rate_of_salaries_Did_not_transition_to_upper_secondary_longterm  \
# 0                                           16.545987
# 1                                           16.881562
# 2                                           18.838816
# 3                                           18.838816
# 4                                           17.355082
# ..                                                ...
# 92                                          17.378273
# 93                                          16.981363
# 94                                          18.838816
# 95                                          19.456336
# 96                                          21.328855
#
#     Total_Never entered primary_return_in_money  \
# 0                                  1.996547e+09
# 1                                  5.048481e+07
# 2                                  9.071690e+08
# 3                                  2.142678e+09
# 4                                  1.654194e+08
# ..                                          ...
# 92                                 1.445526e+08
# 93                                 9.139269e+08
# 94                                 1.138034e+09
# 95                                 3.979373e+08
# 96                                 3.668666e+08
#
#     Total_Dropped out of primary_return_in_money  \
# 0                                   6.048351e+08
# 1                                   3.159979e+07
# 2                                   1.388527e+09
# 3                                   2.915107e+09
# 4                                   7.209968e+08
# ..                                           ...
# 92                                  1.662618e+08
# 93                                  9.182577e+08
# 94                                  1.752543e+09
# 95                                  1.728378e+09
# 96                                  2.653196e+09
#
#     Total_Still attending primary_return_in_money  \
# 0                                    2.502804e+08
# 1                                    4.390051e+06
# 2                                    1.695853e+08
# 3                                    6.852004e+09
# 4                                    1.544993e+09
# ..                                            ...
# 92                                   1.023150e+08
# 93                                   5.739110e+07
# 94                                   6.714289e+08
# 95                                   1.394430e+09
# 96                                   1.635882e+08
#
#     Total_Did not transition to lower secondary_return_in_money  \
# 0                                        3.460158e+08
# 1                                        1.792980e+07
# 2                                        2.145340e+08
# 3                                        5.282400e+08
# 4                                        1.800923e+09
# ..                                                ...
# 92                                       7.629245e+08
# 93                                       8.164429e+08
# 94                                       7.626169e+08
# 95                                       9.035625e+08
# 96                                       2.648930e+09
#
#     Total_Dropped out of lower secondary_return_in_money  \
# 0                                        3.949691e+08
# 1                                        4.121634e+07
# 2                                        6.632170e+09
# 3                                        1.096396e+09
# 4                                        8.305625e+09
# ..                                                ...
# 92                                       1.781907e+09
# 93                                       6.676018e+09
# 94                                       7.045421e+08
# 95                                       5.479807e+08
# 96                                       3.102042e+09
#
#     Total_Still attending lower secondary_return_in_money  \
# 0                                        1.445733e+09
# 1                                        2.749470e+06
# 2                                        1.386136e+10
# 3                                        1.312353e+10
# 4                                        3.989423e+10
# ..                                                ...
# 92                                       5.833224e+09
# 93                                       3.894344e+09
# 94                                       2.956560e+09
# 95                                       2.820663e+09
# 96                                       3.894079e+09
#
#     Total_Did not transition to upper secondary_return_in_money
# 0                                        2.027080e+08
# 1                                        6.556614e+08
# 2                                        1.571258e+09
# 3                                        2.956632e+08
# 4                                        2.539441e+09
# ..                                                ...
# 92                                       7.832437e+08
# 93                                       7.341827e+09
# 94                                       2.379148e+08
# 95                                       6.684642e+08
# 96                                       5.334347e+09
#
# [97 rows x 51 columns]

# %%
data_final['all_return'] = data_final.iloc[:,-7:].sum(axis=1)

# %%
display(data_final)
data_final.to_csv('UNICEF_return_model.csv')
# Out:
#         Country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93      Vietnam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                               30.442579                   2777.983  ...
# 1                               87.067217                    149.990  ...
# 2                               51.285623                   1792.845  ...
# 3                               14.700000                   2209.021  ...
# 4                               59.300000                   2131.984  ...
# ..                                    ...                        ...  ...
# 92                              42.400000                    145.968  ...
# 93                              74.300000                   3929.130  ...
# 94                              31.000000                   1959.731  ...
# 95                              25.788981                   1276.025  ...
# 96                               6.577552                   1332.280  ...
#
#     increasemental_rate_of_salaries_Still_attending_lower_secondary_longterm  \
# 0                                           13.837891
# 1                                           14.376203
# 2                                           17.436179
# 3                                           16.935578
# 4                                           14.888501
# ..                                                ...
# 92                                          14.919316
# 93                                          14.522243
# 94                                          16.935578
# 95                                          18.935241
# 96                                          21.608130
#
#     increasemental_rate_of_salaries_Did_not_transition_to_upper_secondary_longterm  \
# 0                                           16.545987
# 1                                           16.881562
# 2                                           18.838816
# 3                                           18.838816
# 4                                           17.355082
# ..                                                ...
# 92                                          17.378273
# 93                                          16.981363
# 94                                          18.838816
# 95                                          19.456336
# 96                                          21.328855
#
#     Total_Never entered primary_return_in_money  \
# 0                                  1.996547e+09
# 1                                  5.048481e+07
# 2                                  9.071690e+08
# 3                                  2.142678e+09
# 4                                  1.654194e+08
# ..                                          ...
# 92                                 1.445526e+08
# 93                                 9.139269e+08
# 94                                 1.138034e+09
# 95                                 3.979373e+08
# 96                                 3.668666e+08
#
#     Total_Dropped out of primary_return_in_money  \
# 0                                   6.048351e+08
# 1                                   3.159979e+07
# 2                                   1.388527e+09
# 3                                   2.915107e+09
# 4                                   7.209968e+08
# ..                                           ...
# 92                                  1.662618e+08
# 93                                  9.182577e+08
# 94                                  1.752543e+09
# 95                                  1.728378e+09
# 96                                  2.653196e+09
#
#     Total_Still attending primary_return_in_money  \
# 0                                    2.502804e+08
# 1                                    4.390051e+06
# 2                                    1.695853e+08
# 3                                    6.852004e+09
# 4                                    1.544993e+09
# ..                                            ...
# 92                                   1.023150e+08
# 93                                   5.739110e+07
# 94                                   6.714289e+08
# 95                                   1.394430e+09
# 96                                   1.635882e+08
#
#     Total_Did not transition to lower secondary_return_in_money  \
# 0                                        3.460158e+08
# 1                                        1.792980e+07
# 2                                        2.145340e+08
# 3                                        5.282400e+08
# 4                                        1.800923e+09
# ..                                                ...
# 92                                       7.629245e+08
# 93                                       8.164429e+08
# 94                                       7.626169e+08
# 95                                       9.035625e+08
# 96                                       2.648930e+09
#
#     Total_Dropped out of lower secondary_return_in_money  \
# 0                                        3.949691e+08
# 1                                        4.121634e+07
# 2                                        6.632170e+09
# 3                                        1.096396e+09
# 4                                        8.305625e+09
# ..                                                ...
# 92                                       1.781907e+09
# 93                                       6.676018e+09
# 94                                       7.045421e+08
# 95                                       5.479807e+08
# 96                                       3.102042e+09
#
#     Total_Still attending lower secondary_return_in_money  \
# 0                                        1.445733e+09
# 1                                        2.749470e+06
# 2                                        1.386136e+10
# 3                                        1.312353e+10
# 4                                        3.989423e+10
# ..                                                ...
# 92                                       5.833224e+09
# 93                                       3.894344e+09
# 94                                       2.956560e+09
# 95                                       2.820663e+09
# 96                                       3.894079e+09
#
#     Total_Did not transition to upper secondary_return_in_money    all_return
# 0                                        2.027080e+08            5.241088e+09
# 1                                        6.556614e+08            8.040317e+08
# 2                                        1.571258e+09            2.474460e+10
# 3                                        2.956632e+08            2.695362e+10
# 4                                        2.539441e+09            5.497163e+10
# ..                                                ...                     ...
# 92                                       7.832437e+08            9.574429e+09
# 93                                       7.341827e+09            2.061821e+10
# 94                                       2.379148e+08            8.223640e+09
# 95                                       6.684642e+08            8.461415e+09
# 96                                       5.334347e+09            1.816305e+10
#
# [97 rows x 52 columns]

# %%
datapath = Path('/Users/mengliu/Fabdata/Return_models') / 'data' 
total_GDP = pd.read_csv(datapath / 'API_NY.GDP.MKTP.CD_DS2_en_csv_v2_3607744.csv',skiprows=[0,1,2,3])
gpd_data_value = total_GDP.iloc[:,4:].T
gpd_data_value=gpd_data_value.dropna(axis=1,how='all')
gdp_data['GDP']=gpd_data_value.apply(lambda x: x[x.notnull()].values[-1]).T
total_GDP_df = gdp_data[['Country Name','GDP']]
total_GDP_df.rename({'GDP':'GDP_total'},axis='columns',inplace=True)
total_GDP_df[total_GDP_df['Country Name']=='Tanzania']
# Out:
# /var/folders/t8/x02xmt4j0n528hk9zhf852mm0000gn/T/ipykernel_59864/3855602296.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_GDP_df.rename({'GDP':'GDP_total'},axis='columns',inplace=True)
#     Country Name     GDP_total
# 246     Tanzania  6.240971e+10

# %%
total_GDP_df = total_GDP_df.rename({'Country Name':'Country'},axis=1)

data_final = data_final.merge(total_GDP_df,on='Country',how='left')

# %%
data_final['%return per GDP'] = data_final['all_return']/data_final['GDP_total']*100
data_final
# Out:
#         Country  Total_Never entered primary  Total_Dropped out of primary  \
# 0   Afghanistan                    33.861341                      8.254577
# 1       Albania                     1.099108                      0.713800
# 2       Algeria                     2.157483                      3.252027
# 3        Angola                     7.700000                      9.700000
# 4     Argentina                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 92      Uruguay                     1.400000                      1.300000
# 93      Vietnam                     1.700000                      1.600000
# 94        Yemen                    10.800000                     15.400000
# 95       Zambia                     3.524882                     16.126955
# 96     Zimbabwe                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                               30.442579                   2777.983  ...
# 1                               87.067217                    149.990  ...
# 2                               51.285623                   1792.845  ...
# 3                               14.700000                   2209.021  ...
# 4                               59.300000                   2131.984  ...
# ..                                    ...                        ...  ...
# 92                              42.400000                    145.968  ...
# 93                              74.300000                   3929.130  ...
# 94                              31.000000                   1959.731  ...
# 95                              25.788981                   1276.025  ...
# 96                               6.577552                   1332.280  ...
#
#     Total_Never entered primary_return_in_money  \
# 0                                  1.996547e+09
# 1                                  5.048481e+07
# 2                                  9.071690e+08
# 3                                  2.142678e+09
# 4                                  1.654194e+08
# ..                                          ...
# 92                                 1.445526e+08
# 93                                 9.139269e+08
# 94                                 1.138034e+09
# 95                                 3.979373e+08
# 96                                 3.668666e+08
#
#     Total_Dropped out of primary_return_in_money  \
# 0                                   6.048351e+08
# 1                                   3.159979e+07
# 2                                   1.388527e+09
# 3                                   2.915107e+09
# 4                                   7.209968e+08
# ..                                           ...
# 92                                  1.662618e+08
# 93                                  9.182577e+08
# 94                                  1.752543e+09
# 95                                  1.728378e+09
# 96                                  2.653196e+09
#
#     Total_Still attending primary_return_in_money  \
# 0                                    2.502804e+08
# 1                                    4.390051e+06
# 2                                    1.695853e+08
# 3                                    6.852004e+09
# 4                                    1.544993e+09
# ..                                            ...
# 92                                   1.023150e+08
# 93                                   5.739110e+07
# 94                                   6.714289e+08
# 95                                   1.394430e+09
# 96                                   1.635882e+08
#
#     Total_Did not transition to lower secondary_return_in_money  \
# 0                                        3.460158e+08
# 1                                        1.792980e+07
# 2                                        2.145340e+08
# 3                                        5.282400e+08
# 4                                        1.800923e+09
# ..                                                ...
# 92                                       7.629245e+08
# 93                                       8.164429e+08
# 94                                       7.626169e+08
# 95                                       9.035625e+08
# 96                                       2.648930e+09
#
#     Total_Dropped out of lower secondary_return_in_money  \
# 0                                        3.949691e+08
# 1                                        4.121634e+07
# 2                                        6.632170e+09
# 3                                        1.096396e+09
# 4                                        8.305625e+09
# ..                                                ...
# 92                                       1.781907e+09
# 93                                       6.676018e+09
# 94                                       7.045421e+08
# 95                                       5.479807e+08
# 96                                       3.102042e+09
#
#     Total_Still attending lower secondary_return_in_money  \
# 0                                        1.445733e+09
# 1                                        2.749470e+06
# 2                                        1.386136e+10
# 3                                        1.312353e+10
# 4                                        3.989423e+10
# ..                                                ...
# 92                                       5.833224e+09
# 93                                       3.894344e+09
# 94                                       2.956560e+09
# 95                                       2.820663e+09
# 96                                       3.894079e+09
#
#     Total_Did not transition to upper secondary_return_in_money    all_return  \
# 0                                        2.027080e+08            5.241088e+09
# 1                                        6.556614e+08            8.040317e+08
# 2                                        1.571258e+09            2.474460e+10
# 3                                        2.956632e+08            2.695362e+10
# 4                                        2.539441e+09            5.497163e+10
# ..                                                ...                     ...
# 92                                       7.832437e+08            9.574429e+09
# 93                                       7.341827e+09            2.061821e+10
# 94                                       2.379148e+08            8.223640e+09
# 95                                       6.684642e+08            8.461415e+09
# 96                                       5.334347e+09            1.816305e+10
#
#        GDP_total  %return per GDP
# 0   2.011614e+10        26.054148
# 1   1.488763e+10         5.400669
# 2   1.450092e+11        17.064161
# 3   5.837598e+10        46.172454
# 4   3.892881e+11        14.121068
# ..           ...              ...
# 92  5.362883e+10        17.853138
# 93  2.711584e+11         7.603749
# 94           NaN              NaN
# 95  1.811063e+10        46.720707
# 96  1.805117e+10       100.619779
#
# [97 rows x 54 columns]

# %%
data_final.to_csv('return_UNICEF_50%GDP.csv')

# %%
data_final = pd.read_csv('return_UNICEF_50%GDP.csv')

datapath = Path('/Users/mengliu/Fabdata/Return_models') / 'data' 
income_group = pd.read_excel(datapath / 'CLASS.xlsx')
tab_rename = {
    'Congo, Rep.':'Congo',
    'Congo, Dem. Rep.':'Democratic Republic of the Congo',
    'Egypt, Arab Rep.':'Egypt',
    'Lao PDR':'Lao People\'s Democratic Republic',
    'St. Lucia':'Saint Lucia',
    'São Tomé and Principe':'Sao Tome and Principe',
    'Yemen, Rep.':'Yemen'  
}
income_group.replace(tab_rename,inplace=True)
income_group = income_group[['Economy','Income group','Code']]
data_final = data_final.merge(income_group,left_on='Country',right_on='Economy',how='left')
data_final
# Out:
#     Unnamed: 0      Country  Total_Never entered primary  \
# 0            0  Afghanistan                    33.861341
# 1            1      Albania                     1.099108
# 2            2      Algeria                     2.157483
# 3            3       Angola                     7.700000
# 4            4    Argentina                     0.200000
# ..         ...          ...                          ...
# 92          92      Uruguay                     1.400000
# 93          93      Vietnam                     1.700000
# 94          94        Yemen                    10.800000
# 95          95       Zambia                     3.524882
# 96          96     Zimbabwe                     0.336348
#
#     Total_Dropped out of primary  Total_Still attending primary  \
# 0                       8.254577                       3.415739
# 1                       0.713800                       0.099166
# 2                       3.252027                       0.397181
# 3                       9.700000                      22.800000
# 4                       0.700000                       1.500000
# ..                           ...                            ...
# 92                      1.300000                       0.800000
# 93                      1.600000                       0.100000
# 94                     15.400000                       5.900000
# 95                     16.126955                      13.010990
# 96                      6.855908                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  ...  \
# 0                               30.442579  ...
# 1                               87.067217  ...
# 2                               51.285623  ...
# 3                               14.700000  ...
# 4                               59.300000  ...
# ..                                    ...  ...
# 92                              42.400000  ...
# 93                              74.300000  ...
# 94                              31.000000  ...
# 95                              25.788981  ...
# 96                               6.577552  ...
#
#     Total_Did not transition to lower secondary_return_in_money  \
# 0                                        3.460158e+08
# 1                                        1.792980e+07
# 2                                        2.145340e+08
# 3                                        5.282400e+08
# 4                                        1.800923e+09
# ..                                                ...
# 92                                       7.629245e+08
# 93                                       8.164429e+08
# 94                                       7.626169e+08
# 95                                       9.035625e+08
# 96                                       2.648930e+09
#
#     Total_Dropped out of lower secondary_return_in_money  \
# 0                                        3.949691e+08
# 1                                        4.121634e+07
# 2                                        6.632170e+09
# 3                                        1.096396e+09
# 4                                        8.305625e+09
# ..                                                ...
# 92                                       1.781907e+09
# 93                                       6.676018e+09
# 94                                       7.045421e+08
# 95                                       5.479807e+08
# 96                                       3.102042e+09
#
#     Total_Still attending lower secondary_return_in_money  \
# 0                                        1.445733e+09
# 1                                        2.749470e+06
# 2                                        1.386136e+10
# 3                                        1.312353e+10
# 4                                        3.989423e+10
# ..                                                ...
# 92                                       5.833224e+09
# 93                                       3.894344e+09
# 94                                       2.956560e+09
# 95                                       2.820663e+09
# 96                                       3.894079e+09
#
#     Total_Did not transition to upper secondary_return_in_money    all_return  \
# 0                                        2.027080e+08            5.241088e+09
# 1                                        6.556614e+08            8.040317e+08
# 2                                        1.571258e+09            2.474460e+10
# 3                                        2.956632e+08            2.695362e+10
# 4                                        2.539441e+09            5.497163e+10
# ..                                                ...                     ...
# 92                                       7.832437e+08            9.574429e+09
# 93                                       7.341827e+09            2.061821e+10
# 94                                       2.379148e+08            8.223640e+09
# 95                                       6.684642e+08            8.461415e+09
# 96                                       5.334347e+09            1.816305e+10
#
#        GDP_total  %return per GDP      Economy         Income group  Code
# 0   2.011614e+10        26.054148  Afghanistan           Low income   AFG
# 1   1.488763e+10         5.400669      Albania  Upper middle income   ALB
# 2   1.450092e+11        17.064161      Algeria  Lower middle income   DZA
# 3   5.837598e+10        46.172454       Angola  Lower middle income   AGO
# 4   3.892881e+11        14.121068    Argentina  Upper middle income   ARG
# ..           ...              ...          ...                  ...   ...
# 92  5.362883e+10        17.853138      Uruguay          High income   URY
# 93  2.711584e+11         7.603749      Vietnam  Lower middle income   VNM
# 94           NaN              NaN        Yemen           Low income   YEM
# 95  1.811063e+10        46.720707       Zambia  Lower middle income   ZMB
# 96  1.805117e+10       100.619779     Zimbabwe  Lower middle income   ZWE
#
# [97 rows x 58 columns]

# %%
display(data_final[data_final['Income group'].isna()])
tmp = data_final.loc[data_final['Country']=='Kyrgyzstan']
tmp['Income group'] = 'Lower middle income'
data_final[data_final['Country']=='Kyrgyzstan'] = tmp


tmp = data_final.loc[data_final['Country']=='State of Palestine']
tmp['Income group'] = 'Lower middle income'
data_final[data_final['Country']=='State of Palestine'] = tmp
display(data_final[data_final['Income group'].isna()])
# Out:
#     Unnamed: 0             Country  Total_Never entered primary  \
# 48          48          Kyrgyzstan                     0.449410
# 78          78  State of Palestine                     0.738936
#
#     Total_Dropped out of primary  Total_Still attending primary  \
# 48                      0.193854                            0.0
# 78                      0.000000                            0.0
#
#     Total_Did not transition to lower secondary  \
# 48                                     0.000000
# 78                                     0.235853
#
#     Total_Dropped out of lower secondary  \
# 48                              0.425819
# 78                             13.212041
#
#     Total_Still attending lower secondary  \
# 48                               2.526327
# 78                               4.922314
#
#     Total_Did not transition to upper secondary  \
# 48                                    12.361891
# 78                                     4.281132
#
#     Total_Transitioned to upper secondary  ...  \
# 48                              84.042698  ...
# 78                              76.609724  ...
#
#     Total_Did not transition to lower secondary_return_in_money  \
# 48                                                NaN
# 78                                                NaN
#
#     Total_Dropped out of lower secondary_return_in_money  \
# 48                                                NaN
# 78                                                NaN
#
#     Total_Still attending lower secondary_return_in_money  \
# 48                                                NaN
# 78                                                NaN
#
#     Total_Did not transition to upper secondary_return_in_money  all_return  \
# 48                                                NaN                   0.0
# 78                                                NaN                   0.0
#
#     GDP_total  %return per GDP  Economy  Income group  Code
# 48        NaN              NaN      NaN           NaN   NaN
# 78        NaN              NaN      NaN           NaN   NaN
#
# [2 rows x 58 columns]
# /var/folders/t8/x02xmt4j0n528hk9zhf852mm0000gn/T/ipykernel_59864/2948740606.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['Income group'] = 'Lower middle income'
# /var/folders/t8/x02xmt4j0n528hk9zhf852mm0000gn/T/ipykernel_59864/2948740606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['Income group'] = 'Lower middle income'
# Empty DataFrame
# Columns: [Unnamed: 0, Country, Total_Never entered primary, Total_Dropped out of primary, Total_Still attending primary, Total_Did not transition to lower secondary, Total_Dropped out of lower secondary, Total_Still attending lower secondary, Total_Did not transition to upper secondary, Total_Transitioned to upper secondary, Total_population_agerange, Total_Never entered primary_pop, Total_Dropped out of primary_pop, Total_Still attending primary_pop, Total_Did not transition to lower secondary_pop, Total_Dropped out of lower secondary_pop, Total_Still attending lower secondary_pop, Total_Did not transition to upper secondary_pop, Total_Transitioned to upper secondary_pop, primary_dur, lower secondary_dur, upper secondary_dur, GDP, Year, primary_return_rate, secondary_return_rate, increasemental_rate_of_salaries_Never_entered_primary, increasemental_rate_of_Dropped_out_of_primary, increasemental_rate_of_Still_in_primary, increasemental_rate_of_salaries_Did_not_transition_to_lower_secondary, increasemental_rate_of_salaries_Dropped_out_of_lower_secondary, increasemental_rate_of_salaries_Still_in_lower_secondary, increasemental_rate_of_Did_not_transition_to_upper_secondary, year_before_work_primary_full, year_before_work_primary_half, year_before_work_LS_full, year_before_work_LS_half, year_before_work_US_full, increasemental_rate_of_salaries_Never_entered_primary_longterm, increasemental_rate_of_salaries_Dropped_out_of_primary_longterm, increasemental_rate_of_salaries_Still_attending_primary_longterm, increasemental_rate_of_salaries_Did_not_transition_to_lower_secondary_longterm, increasemental_rate_of_salaries_Dropped_out_of_lower_secondary_longterm, increasemental_rate_of_salaries_Still_attending_lower_secondary_longterm, increasemental_rate_of_salaries_Did_not_transition_to_upper_secondary_longterm, Total_Never entered primary_return_in_money, Total_Dropped out of primary_return_in_money, Total_Still attending primary_return_in_money, Total_Did not transition to lower secondary_return_in_money, Total_Dropped out of lower secondary_return_in_money, Total_Still attending lower secondary_return_in_money, Total_Did not transition to upper secondary_return_in_money, all_return, GDP_total, %return per GDP, Economy, Income group, Code]
# Index: []
#
# [0 rows x 58 columns]

# %%
def GDP_to_benefit_poverty(increased_GDP,income_group):
    K ={
     'Low income':0.73,
     'Lower middle income':0.66,
     'Upper middle income':0.51,
     'High income':0.59   
    }
    I = {     
     'Low income':0.455,
     'Lower middle income':0.169,
     'Upper middle income':0.016,
     'High income':0.006   
    }
    N = {     
     'Low income':0.18,
     'Lower middle income':0.043,
     'Upper middle income':0.004,
     'High income':0.004   
    }
    k = K[income_group]
    i = I[income_group]
    j = increased_GDP
    m = i*j*k
    n = N[income_group]
    o = m/(n*1.9*365*(47+8))    
    return o
#Estimated number lifted from extreme poverty
f = GDP_to_benefit_poverty
data_final['benefit_poverty'] = data_final.apply(lambda x: f(x['all_return'], x['Income group']), axis=1) 
data_final
# Out:
#     Unnamed: 0      Country  Total_Never entered primary  \
# 0            0  Afghanistan                    33.861341
# 1            1      Albania                     1.099108
# 2            2      Algeria                     2.157483
# 3            3       Angola                     7.700000
# 4            4    Argentina                     0.200000
# ..         ...          ...                          ...
# 92          92      Uruguay                     1.400000
# 93          93      Vietnam                     1.700000
# 94          94        Yemen                    10.800000
# 95          95       Zambia                     3.524882
# 96          96     Zimbabwe                     0.336348
#
#     Total_Dropped out of primary  Total_Still attending primary  \
# 0                       8.254577                       3.415739
# 1                       0.713800                       0.099166
# 2                       3.252027                       0.397181
# 3                       9.700000                      22.800000
# 4                       0.700000                       1.500000
# ..                           ...                            ...
# 92                      1.300000                       0.800000
# 93                      1.600000                       0.100000
# 94                     15.400000                       5.900000
# 95                     16.126955                      13.010990
# 96                      6.855908                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  ...  \
# 0                               30.442579  ...
# 1                               87.067217  ...
# 2                               51.285623  ...
# 3                               14.700000  ...
# 4                               59.300000  ...
# ..                                    ...  ...
# 92                              42.400000  ...
# 93                              74.300000  ...
# 94                              31.000000  ...
# 95                              25.788981  ...
# 96                               6.577552  ...
#
#     Total_Dropped out of lower secondary_return_in_money  \
# 0                                        3.949691e+08
# 1                                        4.121634e+07
# 2                                        6.632170e+09
# 3                                        1.096396e+09
# 4                                        8.305625e+09
# ..                                                ...
# 92                                       1.781907e+09
# 93                                       6.676018e+09
# 94                                       7.045421e+08
# 95                                       5.479807e+08
# 96                                       3.102042e+09
#
#     Total_Still attending lower secondary_return_in_money  \
# 0                                        1.445733e+09
# 1                                        2.749470e+06
# 2                                        1.386136e+10
# 3                                        1.312353e+10
# 4                                        3.989423e+10
# ..                                                ...
# 92                                       5.833224e+09
# 93                                       3.894344e+09
# 94                                       2.956560e+09
# 95                                       2.820663e+09
# 96                                       3.894079e+09
#
#     Total_Did not transition to upper secondary_return_in_money    all_return  \
# 0                                        2.027080e+08            5.241088e+09
# 1                                        6.556614e+08            8.040317e+08
# 2                                        1.571258e+09            2.474460e+10
# 3                                        2.956632e+08            2.695362e+10
# 4                                        2.539441e+09            5.497163e+10
# ..                                                ...                     ...
# 92                                       7.832437e+08            9.574429e+09
# 93                                       7.341827e+09            2.061821e+10
# 94                                       2.379148e+08            8.223640e+09
# 95                                       6.684642e+08            8.461415e+09
# 96                                       5.334347e+09            1.816305e+10
#
#        GDP_total  %return per GDP      Economy         Income group  Code  \
# 0   2.011614e+10        26.054148  Afghanistan           Low income   AFG
# 1   1.488763e+10         5.400669      Albania  Upper middle income   ALB
# 2   1.450092e+11        17.064161      Algeria  Lower middle income   DZA
# 3   5.837598e+10        46.172454       Angola  Lower middle income   AGO
# 4   3.892881e+11        14.121068    Argentina  Upper middle income   ARG
# ..           ...              ...          ...                  ...   ...
# 92  5.362883e+10        17.853138      Uruguay          High income   URY
# 93  2.711584e+11         7.603749      Vietnam  Lower middle income   VNM
# 94           NaN              NaN        Yemen           Low income   YEM
# 95  1.811063e+10        46.720707       Zambia  Lower middle income   ZMB
# 96  1.805117e+10       100.619779     Zimbabwe  Lower middle income   ZWE
#
#     benefit_poverty
# 0      2.535561e+05
# 1      4.300254e+04
# 2      1.682804e+06
# 3      1.833032e+06
# 4      2.940083e+06
# ..              ...
# 92     2.221503e+05
# 93     1.402181e+06
# 94     3.978476e+05
# 95     5.754347e+05
# 96     1.235213e+06
#
# [97 rows x 59 columns]

# %%
# tax share 


def GDP_to_benefit_revenue(increased_GDP,income_group):
    P ={
     'Low income':0.1207,
     'Lower middle income':0.1441,
     'Upper middle income':0.1545,
     'High income':0.1852   
    }
    p = P[income_group]
    j = increased_GDP
    q = j * p    
    return q
f = GDP_to_benefit_revenue
#Public revenue generated
data_final['benefit_revenue'] = data_final.apply(lambda x: f(x['all_return'], x['Income group']), axis=1) 
data_final = data_final.iloc[:,1:]
#data_final.drop('Economy_y',axis=1)
data_final.to_csv('return_UNICEF_benefit.csv')

data_final
# Out:
#     Total_Never entered primary  Total_Dropped out of primary  \
# 0                     33.861341                      8.254577
# 1                      1.099108                      0.713800
# 2                      2.157483                      3.252027
# 3                      7.700000                      9.700000
# 4                      0.200000                      0.700000
# ..                          ...                           ...
# 92                     1.400000                      1.300000
# 93                     1.700000                      1.600000
# 94                    10.800000                     15.400000
# 95                     3.524882                     16.126955
# 96                     0.336348                      6.855908
#
#     Total_Still attending primary  \
# 0                        3.415739
# 1                        0.099166
# 2                        0.397181
# 3                       22.800000
# 4                        1.500000
# ..                            ...
# 92                       0.800000
# 93                       0.100000
# 94                       5.900000
# 95                      13.010990
# 96                       0.422715
#
#     Total_Did not transition to lower secondary  \
# 0                                      3.786342
# 1                                      0.371935
# 2                                      0.444625
# 3                                      1.600000
# 4                                      1.400000
# ..                                          ...
# 92                                     4.800000
# 93                                     1.200000
# 94                                     6.100000
# 95                                     7.777071
# 96                                    14.874372
#
#     Total_Dropped out of lower secondary  \
# 0                               3.976628
# 1                               0.728686
# 2                              12.831457
# 3                               3.300000
# 4                               6.100000
# ..                                   ...
# 92                             10.600000
# 93                              8.400000
# 94                              5.600000
# 95                              4.604374
# 96                             17.744506
#
#     Total_Still attending lower secondary  \
# 0                               14.555927
# 1                                0.048609
# 2                               26.817983
# 3                               39.500000
# 4                               29.300000
# ..                                    ...
# 92                              34.700000
# 93                               4.900000
# 94                              23.500000
# 95                              23.700449
# 96                              22.275173
#
#     Total_Did not transition to upper secondary  \
# 0                                      1.706868
# 1                                      9.871478
# 2                                      2.813620
# 3                                      0.800000
# 4                                      1.600000
# ..                                          ...
# 92                                     4.000000
# 93                                     7.900000
# 94                                     1.700000
# 95                                     5.466298
# 96                                    30.913427
#
#     Total_Transitioned to upper secondary  Total_population_agerange  \
# 0                               30.442579                   2777.983
# 1                               87.067217                    149.990
# 2                               51.285623                   1792.845
# 3                               14.700000                   2209.021
# 4                               59.300000                   2131.984
# ..                                    ...                        ...
# 92                              42.400000                    145.968
# 93                              74.300000                   3929.130
# 94                              31.000000                   1959.731
# 95                              25.788981                   1276.025
# 96                               6.577552                   1332.280
#
#     Total_Never entered primary_pop  ...  \
# 0                     940662.293496  ...
# 1                       1648.552290  ...
# 2                      38680.317844  ...
# 3                     170094.617000  ...
# 4                       4263.968000  ...
# ..                              ...  ...
# 92                      2043.552000  ...
# 93                     66795.210000  ...
# 94                    211650.948000  ...
# 95                     44978.377455  ...
# 96                      4481.091366  ...
#
#     Total_Still attending lower secondary_return_in_money  \
# 0                                        1.445733e+09
# 1                                        2.749470e+06
# 2                                        1.386136e+10
# 3                                        1.312353e+10
# 4                                        3.989423e+10
# ..                                                ...
# 92                                       5.833224e+09
# 93                                       3.894344e+09
# 94                                       2.956560e+09
# 95                                       2.820663e+09
# 96                                       3.894079e+09
#
#     Total_Did not transition to upper secondary_return_in_money    all_return  \
# 0                                        2.027080e+08            5.241088e+09
# 1                                        6.556614e+08            8.040317e+08
# 2                                        1.571258e+09            2.474460e+10
# 3                                        2.956632e+08            2.695362e+10
# 4                                        2.539441e+09            5.497163e+10
# ..                                                ...                     ...
# 92                                       7.832437e+08            9.574429e+09
# 93                                       7.341827e+09            2.061821e+10
# 94                                       2.379148e+08            8.223640e+09
# 95                                       6.684642e+08            8.461415e+09
# 96                                       5.334347e+09            1.816305e+10
#
#        GDP_total  %return per GDP      Economy         Income group  Code  \
# 0   2.011614e+10        26.054148  Afghanistan           Low income   AFG
# 1   1.488763e+10         5.400669      Albania  Upper middle income   ALB
# 2   1.450092e+11        17.064161      Algeria  Lower middle income   DZA
# 3   5.837598e+10        46.172454       Angola  Lower middle income   AGO
# 4   3.892881e+11        14.121068    Argentina  Upper middle income   ARG
# ..           ...              ...          ...                  ...   ...
# 92  5.362883e+10        17.853138      Uruguay          High income   URY
# 93  2.711584e+11         7.603749      Vietnam  Lower middle income   VNM
# 94           NaN              NaN        Yemen           Low income   YEM
# 95  1.811063e+10        46.720707       Zambia  Lower middle income   ZMB
# 96  1.805117e+10       100.619779     Zimbabwe  Lower middle income   ZWE
#
#     benefit_poverty  benefit_revenue
# 0      2.535561e+05     6.325993e+08
# 1      4.300254e+04     1.242229e+08
# 2      1.682804e+06     3.565697e+09
# 3      1.833032e+06     3.884017e+09
# 4      2.940083e+06     8.493117e+09
# ..              ...              ...
# 92     2.221503e+05     1.773184e+09
# 93     1.402181e+06     2.971084e+09
# 94     3.978476e+05     9.925934e+08
# 95     5.754347e+05     1.219290e+09
# 96     1.235213e+06     2.617295e+09
#
# [97 rows x 58 columns]

# %%
data_final = pd.read_csv('return_UNICEF_benefit.csv')

datapath = Path('/Users/mengliu/Fabdata/Return_models') / 'data' 
hlo_group = pd.read_csv(datapath / 'hlo_Data.csv',na_values='..')
hlo_group = hlo_group[['Country Code','2020 [YR2020]']]
hlo_group = hlo_group.rename({'Country Code':'Code','2020 [YR2020]':'HLO'},axis=1)
data_final = data_final.merge(hlo_group,on='Code',how='left')
data_final
# Out:
#      Unnamed: 0  Total_Never entered primary  Total_Dropped out of primary  \
# 0             0                    33.861341                      8.254577
# 1             1                     1.099108                      0.713800
# 2             2                     2.157483                      3.252027
# 3             3                     7.700000                      9.700000
# 4             4                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 100          92                     1.400000                      1.300000
# 101          93                     1.700000                      1.600000
# 102          94                    10.800000                     15.400000
# 103          95                     3.524882                     16.126955
# 104          96                     0.336348                      6.855908
#
#      Total_Still attending primary  \
# 0                         3.415739
# 1                         0.099166
# 2                         0.397181
# 3                        22.800000
# 4                         1.500000
# ..                             ...
# 100                       0.800000
# 101                       0.100000
# 102                       5.900000
# 103                      13.010990
# 104                       0.422715
#
#      Total_Did not transition to lower secondary  \
# 0                                       3.786342
# 1                                       0.371935
# 2                                       0.444625
# 3                                       1.600000
# 4                                       1.400000
# ..                                           ...
# 100                                     4.800000
# 101                                     1.200000
# 102                                     6.100000
# 103                                     7.777071
# 104                                    14.874372
#
#      Total_Dropped out of lower secondary  \
# 0                                3.976628
# 1                                0.728686
# 2                               12.831457
# 3                                3.300000
# 4                                6.100000
# ..                                    ...
# 100                             10.600000
# 101                              8.400000
# 102                              5.600000
# 103                              4.604374
# 104                             17.744506
#
#      Total_Still attending lower secondary  \
# 0                                14.555927
# 1                                 0.048609
# 2                                26.817983
# 3                                39.500000
# 4                                29.300000
# ..                                     ...
# 100                              34.700000
# 101                               4.900000
# 102                              23.500000
# 103                              23.700449
# 104                              22.275173
#
#      Total_Did not transition to upper secondary  \
# 0                                       1.706868
# 1                                       9.871478
# 2                                       2.813620
# 3                                       0.800000
# 4                                       1.600000
# ..                                           ...
# 100                                     4.000000
# 101                                     7.900000
# 102                                     1.700000
# 103                                     5.466298
# 104                                    30.913427
#
#      Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                                30.442579                   2777.983  ...
# 1                                87.067217                    149.990  ...
# 2                                51.285623                   1792.845  ...
# 3                                14.700000                   2209.021  ...
# 4                                59.300000                   2131.984  ...
# ..                                     ...                        ...  ...
# 100                              42.400000                    145.968  ...
# 101                              74.300000                   3929.130  ...
# 102                              31.000000                   1959.731  ...
# 103                              25.788981                   1276.025  ...
# 104                               6.577552                   1332.280  ...
#
#      Total_Did not transition to upper secondary_return_in_money  \
# 0                                         2.027080e+08
# 1                                         6.556614e+08
# 2                                         1.571258e+09
# 3                                         2.956632e+08
# 4                                         2.539441e+09
# ..                                                 ...
# 100                                       7.832437e+08
# 101                                       7.341827e+09
# 102                                       2.379148e+08
# 103                                       6.684642e+08
# 104                                       5.334347e+09
#
#        all_return     GDP_total  %return per GDP      Economy  \
# 0    5.241088e+09  2.011614e+10        26.054148  Afghanistan
# 1    8.040317e+08  1.488763e+10         5.400669      Albania
# 2    2.474460e+10  1.450092e+11        17.064161      Algeria
# 3    2.695362e+10  5.837598e+10        46.172454       Angola
# 4    5.497163e+10  3.892881e+11        14.121068    Argentina
# ..            ...           ...              ...          ...
# 100  9.574429e+09  5.362883e+10        17.853138      Uruguay
# 101  2.061821e+10  2.711584e+11         7.603749      Vietnam
# 102  8.223640e+09           NaN              NaN        Yemen
# 103  8.461415e+09  1.811063e+10        46.720707       Zambia
# 104  1.816305e+10  1.805117e+10       100.619779     Zimbabwe
#
#             Income group  Code  benefit_poverty  benefit_revenue         HLO
# 0             Low income   AFG     2.535561e+05     6.325993e+08  354.758789
# 1    Upper middle income   ALB     4.300254e+04     1.242229e+08  434.127594
# 2    Lower middle income   DZA     1.682804e+06     3.565697e+09  374.089081
# 3    Lower middle income   AGO     1.833032e+06     3.884017e+09  325.965485
# 4    Upper middle income   ARG     2.940083e+06     8.493117e+09  408.172638
# ..                   ...   ...              ...              ...         ...
# 100          High income   URY     2.221503e+05     1.773184e+09  437.696625
# 101  Lower middle income   VNM     1.402181e+06     2.971084e+09  519.100281
# 102           Low income   YEM     3.978476e+05     9.925934e+08  321.327026
# 103  Lower middle income   ZMB     5.754347e+05     1.219290e+09  358.140442
# 104  Lower middle income   ZWE     1.235213e+06     2.617295e+09  396.138824
#
# [105 rows x 60 columns]

# %%
data_final_tmp = data_final[['Income group','HLO']]
HLO_average_group = data_final_tmp.groupby(['Income group']).mean().reset_index()
for gi in HLO_average_group['Income group'].values:

    data_final.loc[data_final['Income group']==gi,'HLO_average'] = HLO_average_group[HLO_average_group['Income group']==gi]['HLO'].values[0]
data_final
# Out:
#      Unnamed: 0  Total_Never entered primary  Total_Dropped out of primary  \
# 0             0                    33.861341                      8.254577
# 1             1                     1.099108                      0.713800
# 2             2                     2.157483                      3.252027
# 3             3                     7.700000                      9.700000
# 4             4                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 100          92                     1.400000                      1.300000
# 101          93                     1.700000                      1.600000
# 102          94                    10.800000                     15.400000
# 103          95                     3.524882                     16.126955
# 104          96                     0.336348                      6.855908
#
#      Total_Still attending primary  \
# 0                         3.415739
# 1                         0.099166
# 2                         0.397181
# 3                        22.800000
# 4                         1.500000
# ..                             ...
# 100                       0.800000
# 101                       0.100000
# 102                       5.900000
# 103                      13.010990
# 104                       0.422715
#
#      Total_Did not transition to lower secondary  \
# 0                                       3.786342
# 1                                       0.371935
# 2                                       0.444625
# 3                                       1.600000
# 4                                       1.400000
# ..                                           ...
# 100                                     4.800000
# 101                                     1.200000
# 102                                     6.100000
# 103                                     7.777071
# 104                                    14.874372
#
#      Total_Dropped out of lower secondary  \
# 0                                3.976628
# 1                                0.728686
# 2                               12.831457
# 3                                3.300000
# 4                                6.100000
# ..                                    ...
# 100                             10.600000
# 101                              8.400000
# 102                              5.600000
# 103                              4.604374
# 104                             17.744506
#
#      Total_Still attending lower secondary  \
# 0                                14.555927
# 1                                 0.048609
# 2                                26.817983
# 3                                39.500000
# 4                                29.300000
# ..                                     ...
# 100                              34.700000
# 101                               4.900000
# 102                              23.500000
# 103                              23.700449
# 104                              22.275173
#
#      Total_Did not transition to upper secondary  \
# 0                                       1.706868
# 1                                       9.871478
# 2                                       2.813620
# 3                                       0.800000
# 4                                       1.600000
# ..                                           ...
# 100                                     4.000000
# 101                                     7.900000
# 102                                     1.700000
# 103                                     5.466298
# 104                                    30.913427
#
#      Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                                30.442579                   2777.983  ...
# 1                                87.067217                    149.990  ...
# 2                                51.285623                   1792.845  ...
# 3                                14.700000                   2209.021  ...
# 4                                59.300000                   2131.984  ...
# ..                                     ...                        ...  ...
# 100                              42.400000                    145.968  ...
# 101                              74.300000                   3929.130  ...
# 102                              31.000000                   1959.731  ...
# 103                              25.788981                   1276.025  ...
# 104                               6.577552                   1332.280  ...
#
#        all_return     GDP_total  %return per GDP      Economy  \
# 0    5.241088e+09  2.011614e+10        26.054148  Afghanistan
# 1    8.040317e+08  1.488763e+10         5.400669      Albania
# 2    2.474460e+10  1.450092e+11        17.064161      Algeria
# 3    2.695362e+10  5.837598e+10        46.172454       Angola
# 4    5.497163e+10  3.892881e+11        14.121068    Argentina
# ..            ...           ...              ...          ...
# 100  9.574429e+09  5.362883e+10        17.853138      Uruguay
# 101  2.061821e+10  2.711584e+11         7.603749      Vietnam
# 102  8.223640e+09           NaN              NaN        Yemen
# 103  8.461415e+09  1.811063e+10        46.720707       Zambia
# 104  1.816305e+10  1.805117e+10       100.619779     Zimbabwe
#
#             Income group  Code  benefit_poverty  benefit_revenue         HLO  \
# 0             Low income   AFG     2.535561e+05     6.325993e+08  354.758789
# 1    Upper middle income   ALB     4.300254e+04     1.242229e+08  434.127594
# 2    Lower middle income   DZA     1.682804e+06     3.565697e+09  374.089081
# 3    Lower middle income   AGO     1.833032e+06     3.884017e+09  325.965485
# 4    Upper middle income   ARG     2.940083e+06     8.493117e+09  408.172638
# ..                   ...   ...              ...              ...         ...
# 100          High income   URY     2.221503e+05     1.773184e+09  437.696625
# 101  Lower middle income   VNM     1.402181e+06     2.971084e+09  519.100281
# 102           Low income   YEM     3.978476e+05     9.925934e+08  321.327026
# 103  Lower middle income   ZMB     5.754347e+05     1.219290e+09  358.140442
# 104  Lower middle income   ZWE     1.235213e+06     2.617295e+09  396.138824
#
#      HLO_average
# 0     355.407968
# 1     413.097653
# 2     387.426556
# 3     387.426556
# 4     413.097653
# ..           ...
# 100   437.696625
# 101   387.426556
# 102   355.407968
# 103   387.426556
# 104   387.426556
#
# [105 rows x 61 columns]

# %%
datapath = Path('/Users/mengliu/Fabdata/Return_models') / 'data' 
total_pop = pd.read_csv(datapath / 'Total_population_worldbank.csv',na_values='..')
total_pop = total_pop[['Country Code','2020']]
total_pop = total_pop.rename({'Country Code':'Code','2020':'Total_pop'},axis=1)
data_final_tmp = data_final.merge(total_pop,on='Code',how='left')
data_final_tmp = data_final_tmp[['Income group','Total_pop','HLO']]
data_final['total_pop'] = data_final_tmp.Total_pop
data_final_tmp = data_final_tmp.dropna()
data_final_tmp = data_final_tmp.groupby(['Income group']).apply(lambda x:np.average(x['HLO'],weights=x['Total_pop'])).to_frame(name='weighted_avergage_hlo').reset_index()
data_final_tmp
for gi in data_final_tmp['Income group'].values:
       data_final.loc[data_final['Income group']==gi,'HLO_weighted_average'] = data_final_tmp[data_final_tmp['Income group']==gi].values[0][1]

data_final.to_csv('return_UNICEF_benefit_with_weightHLO.csv')
data_final
# Out:
#      Unnamed: 0  Total_Never entered primary  Total_Dropped out of primary  \
# 0             0                    33.861341                      8.254577
# 1             1                     1.099108                      0.713800
# 2             2                     2.157483                      3.252027
# 3             3                     7.700000                      9.700000
# 4             4                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 100          92                     1.400000                      1.300000
# 101          93                     1.700000                      1.600000
# 102          94                    10.800000                     15.400000
# 103          95                     3.524882                     16.126955
# 104          96                     0.336348                      6.855908
#
#      Total_Still attending primary  \
# 0                         3.415739
# 1                         0.099166
# 2                         0.397181
# 3                        22.800000
# 4                         1.500000
# ..                             ...
# 100                       0.800000
# 101                       0.100000
# 102                       5.900000
# 103                      13.010990
# 104                       0.422715
#
#      Total_Did not transition to lower secondary  \
# 0                                       3.786342
# 1                                       0.371935
# 2                                       0.444625
# 3                                       1.600000
# 4                                       1.400000
# ..                                           ...
# 100                                     4.800000
# 101                                     1.200000
# 102                                     6.100000
# 103                                     7.777071
# 104                                    14.874372
#
#      Total_Dropped out of lower secondary  \
# 0                                3.976628
# 1                                0.728686
# 2                               12.831457
# 3                                3.300000
# 4                                6.100000
# ..                                    ...
# 100                             10.600000
# 101                              8.400000
# 102                              5.600000
# 103                              4.604374
# 104                             17.744506
#
#      Total_Still attending lower secondary  \
# 0                                14.555927
# 1                                 0.048609
# 2                                26.817983
# 3                                39.500000
# 4                                29.300000
# ..                                     ...
# 100                              34.700000
# 101                               4.900000
# 102                              23.500000
# 103                              23.700449
# 104                              22.275173
#
#      Total_Did not transition to upper secondary  \
# 0                                       1.706868
# 1                                       9.871478
# 2                                       2.813620
# 3                                       0.800000
# 4                                       1.600000
# ..                                           ...
# 100                                     4.000000
# 101                                     7.900000
# 102                                     1.700000
# 103                                     5.466298
# 104                                    30.913427
#
#      Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                                30.442579                   2777.983  ...
# 1                                87.067217                    149.990  ...
# 2                                51.285623                   1792.845  ...
# 3                                14.700000                   2209.021  ...
# 4                                59.300000                   2131.984  ...
# ..                                     ...                        ...  ...
# 100                              42.400000                    145.968  ...
# 101                              74.300000                   3929.130  ...
# 102                              31.000000                   1959.731  ...
# 103                              25.788981                   1276.025  ...
# 104                               6.577552                   1332.280  ...
#
#      %return per GDP      Economy         Income group  Code  benefit_poverty  \
# 0          26.054148  Afghanistan           Low income   AFG     2.535561e+05
# 1           5.400669      Albania  Upper middle income   ALB     4.300254e+04
# 2          17.064161      Algeria  Lower middle income   DZA     1.682804e+06
# 3          46.172454       Angola  Lower middle income   AGO     1.833032e+06
# 4          14.121068    Argentina  Upper middle income   ARG     2.940083e+06
# ..               ...          ...                  ...   ...              ...
# 100        17.853138      Uruguay          High income   URY     2.221503e+05
# 101         7.603749      Vietnam  Lower middle income   VNM     1.402181e+06
# 102              NaN        Yemen           Low income   YEM     3.978476e+05
# 103        46.720707       Zambia  Lower middle income   ZMB     5.754347e+05
# 104       100.619779     Zimbabwe  Lower middle income   ZWE     1.235213e+06
#
#      benefit_revenue         HLO  HLO_average   total_pop  \
# 0       6.325993e+08  354.758789   355.407968  38928341.0
# 1       1.242229e+08  434.127594   413.097653   2837743.0
# 2       3.565697e+09  374.089081   387.426556  43851043.0
# 3       3.884017e+09  325.965485   387.426556  32866268.0
# 4       8.493117e+09  408.172638   413.097653  45376763.0
# ..               ...         ...          ...         ...
# 100     1.773184e+09  437.696625   437.696625   3473727.0
# 101     2.971084e+09  519.100281   387.426556  97338583.0
# 102     9.925934e+08  321.327026   355.407968  29825968.0
# 103     1.219290e+09  358.140442   387.426556  18383956.0
# 104     2.617295e+09  396.138824   387.426556  14862927.0
#
#      HLO_weighted_average
# 0              350.427762
# 1              414.282878
# 2              387.205977
# 3              387.205977
# 4              414.282878
# ..                    ...
# 100            437.696625
# 101            387.205977
# 102            350.427762
# 103            387.205977
# 104            387.205977
#
# [105 rows x 63 columns]

# %%
# LAYS  = number of children * HLO / 650
# 
# devide 650 
data_final['LAYS'] = (data_final['year_before_work_primary_full']*data_final['HLO_weighted_average']/650*data_final['Total_Never entered primary_pop'] +
                      data_final['year_before_work_primary_half']*data_final['HLO_weighted_average']/650*data_final['Total_Dropped out of primary_pop'] +
                      data_final['year_before_work_primary_half']*data_final['HLO_weighted_average']/650*data_final['Total_Still attending primary_pop'] +
                     
                      data_final['year_before_work_LS_full']*data_final['HLO_weighted_average']/650*data_final['Total_Did not transition to lower secondary_pop'] +
                      data_final['year_before_work_LS_half']*data_final['HLO_weighted_average']/650*data_final['Total_Dropped out of lower secondary_pop'] +
                      data_final['year_before_work_LS_half']*data_final['HLO_weighted_average']/650*data_final['Total_Still attending lower secondary_pop'] +

                      data_final['year_before_work_US_full']*data_final['HLO_weighted_average']/650*data_final['Total_Did not transition to upper secondary_pop'] 

                      )
data_final
# Out:
#      Unnamed: 0  Total_Never entered primary  Total_Dropped out of primary  \
# 0             0                    33.861341                      8.254577
# 1             1                     1.099108                      0.713800
# 2             2                     2.157483                      3.252027
# 3             3                     7.700000                      9.700000
# 4             4                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 100          92                     1.400000                      1.300000
# 101          93                     1.700000                      1.600000
# 102          94                    10.800000                     15.400000
# 103          95                     3.524882                     16.126955
# 104          96                     0.336348                      6.855908
#
#      Total_Still attending primary  \
# 0                         3.415739
# 1                         0.099166
# 2                         0.397181
# 3                        22.800000
# 4                         1.500000
# ..                             ...
# 100                       0.800000
# 101                       0.100000
# 102                       5.900000
# 103                      13.010990
# 104                       0.422715
#
#      Total_Did not transition to lower secondary  \
# 0                                       3.786342
# 1                                       0.371935
# 2                                       0.444625
# 3                                       1.600000
# 4                                       1.400000
# ..                                           ...
# 100                                     4.800000
# 101                                     1.200000
# 102                                     6.100000
# 103                                     7.777071
# 104                                    14.874372
#
#      Total_Dropped out of lower secondary  \
# 0                                3.976628
# 1                                0.728686
# 2                               12.831457
# 3                                3.300000
# 4                                6.100000
# ..                                    ...
# 100                             10.600000
# 101                              8.400000
# 102                              5.600000
# 103                              4.604374
# 104                             17.744506
#
#      Total_Still attending lower secondary  \
# 0                                14.555927
# 1                                 0.048609
# 2                                26.817983
# 3                                39.500000
# 4                                29.300000
# ..                                     ...
# 100                              34.700000
# 101                               4.900000
# 102                              23.500000
# 103                              23.700449
# 104                              22.275173
#
#      Total_Did not transition to upper secondary  \
# 0                                       1.706868
# 1                                       9.871478
# 2                                       2.813620
# 3                                       0.800000
# 4                                       1.600000
# ..                                           ...
# 100                                     4.000000
# 101                                     7.900000
# 102                                     1.700000
# 103                                     5.466298
# 104                                    30.913427
#
#      Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                                30.442579                   2777.983  ...
# 1                                87.067217                    149.990  ...
# 2                                51.285623                   1792.845  ...
# 3                                14.700000                   2209.021  ...
# 4                                59.300000                   2131.984  ...
# ..                                     ...                        ...  ...
# 100                              42.400000                    145.968  ...
# 101                              74.300000                   3929.130  ...
# 102                              31.000000                   1959.731  ...
# 103                              25.788981                   1276.025  ...
# 104                               6.577552                   1332.280  ...
#
#          Economy         Income group  Code  benefit_poverty  benefit_revenue  \
# 0    Afghanistan           Low income   AFG     2.535561e+05     6.325993e+08
# 1        Albania  Upper middle income   ALB     4.300254e+04     1.242229e+08
# 2        Algeria  Lower middle income   DZA     1.682804e+06     3.565697e+09
# 3         Angola  Lower middle income   AGO     1.833032e+06     3.884017e+09
# 4      Argentina  Upper middle income   ARG     2.940083e+06     8.493117e+09
# ..           ...                  ...   ...              ...              ...
# 100      Uruguay          High income   URY     2.221503e+05     1.773184e+09
# 101      Vietnam  Lower middle income   VNM     1.402181e+06     2.971084e+09
# 102        Yemen           Low income   YEM     3.978476e+05     9.925934e+08
# 103       Zambia  Lower middle income   ZMB     5.754347e+05     1.219290e+09
# 104     Zimbabwe  Lower middle income   ZWE     1.235213e+06     2.617295e+09
#
#             HLO  HLO_average   total_pop  HLO_weighted_average          LAYS
# 0    354.758789   355.407968  38928341.0            350.427762  9.324525e+06
# 1    434.127594   413.097653   2837743.0            414.282878  5.450669e+04
# 2    374.089081   387.426556  43851043.0            387.205977  2.887422e+06
# 3    325.965485   387.426556  32866268.0            387.205977  7.757331e+06
# 4    408.172638   413.097653  45376763.0            414.282878  2.645657e+06
# ..          ...          ...         ...                   ...           ...
# 100  437.696625   437.696625   3473727.0            437.696625  2.755612e+05
# 101  519.100281   387.426556  97338583.0            387.205977  3.163306e+06
# 102  321.327026   355.407968  29825968.0            350.427762  5.218727e+06
# 103  358.140442   387.426556  18383956.0            387.205977  3.485003e+06
# 104  396.138824   387.426556  14862927.0            387.205977  3.861205e+06
#
# [105 rows x 64 columns]

# %%
def GDP_to_benefit_lives(LAYS,total_pop):
    b = LAYS
    r = total_pop
    s = 0.0155 * b / r
    t = s * r
    return t
f = GDP_to_benefit_lives
#Public revenue generated
data_final['benefit_lives'] = data_final.apply(lambda x: f(x['LAYS'], x['total_pop']), axis=1) 

data_final
# Out:
#      Unnamed: 0  Total_Never entered primary  Total_Dropped out of primary  \
# 0             0                    33.861341                      8.254577
# 1             1                     1.099108                      0.713800
# 2             2                     2.157483                      3.252027
# 3             3                     7.700000                      9.700000
# 4             4                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 100          92                     1.400000                      1.300000
# 101          93                     1.700000                      1.600000
# 102          94                    10.800000                     15.400000
# 103          95                     3.524882                     16.126955
# 104          96                     0.336348                      6.855908
#
#      Total_Still attending primary  \
# 0                         3.415739
# 1                         0.099166
# 2                         0.397181
# 3                        22.800000
# 4                         1.500000
# ..                             ...
# 100                       0.800000
# 101                       0.100000
# 102                       5.900000
# 103                      13.010990
# 104                       0.422715
#
#      Total_Did not transition to lower secondary  \
# 0                                       3.786342
# 1                                       0.371935
# 2                                       0.444625
# 3                                       1.600000
# 4                                       1.400000
# ..                                           ...
# 100                                     4.800000
# 101                                     1.200000
# 102                                     6.100000
# 103                                     7.777071
# 104                                    14.874372
#
#      Total_Dropped out of lower secondary  \
# 0                                3.976628
# 1                                0.728686
# 2                               12.831457
# 3                                3.300000
# 4                                6.100000
# ..                                    ...
# 100                             10.600000
# 101                              8.400000
# 102                              5.600000
# 103                              4.604374
# 104                             17.744506
#
#      Total_Still attending lower secondary  \
# 0                                14.555927
# 1                                 0.048609
# 2                                26.817983
# 3                                39.500000
# 4                                29.300000
# ..                                     ...
# 100                              34.700000
# 101                               4.900000
# 102                              23.500000
# 103                              23.700449
# 104                              22.275173
#
#      Total_Did not transition to upper secondary  \
# 0                                       1.706868
# 1                                       9.871478
# 2                                       2.813620
# 3                                       0.800000
# 4                                       1.600000
# ..                                           ...
# 100                                     4.000000
# 101                                     7.900000
# 102                                     1.700000
# 103                                     5.466298
# 104                                    30.913427
#
#      Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                                30.442579                   2777.983  ...
# 1                                87.067217                    149.990  ...
# 2                                51.285623                   1792.845  ...
# 3                                14.700000                   2209.021  ...
# 4                                59.300000                   2131.984  ...
# ..                                     ...                        ...  ...
# 100                              42.400000                    145.968  ...
# 101                              74.300000                   3929.130  ...
# 102                              31.000000                   1959.731  ...
# 103                              25.788981                   1276.025  ...
# 104                               6.577552                   1332.280  ...
#
#             Income group  Code  benefit_poverty  benefit_revenue         HLO  \
# 0             Low income   AFG     2.535561e+05     6.325993e+08  354.758789
# 1    Upper middle income   ALB     4.300254e+04     1.242229e+08  434.127594
# 2    Lower middle income   DZA     1.682804e+06     3.565697e+09  374.089081
# 3    Lower middle income   AGO     1.833032e+06     3.884017e+09  325.965485
# 4    Upper middle income   ARG     2.940083e+06     8.493117e+09  408.172638
# ..                   ...   ...              ...              ...         ...
# 100          High income   URY     2.221503e+05     1.773184e+09  437.696625
# 101  Lower middle income   VNM     1.402181e+06     2.971084e+09  519.100281
# 102           Low income   YEM     3.978476e+05     9.925934e+08  321.327026
# 103  Lower middle income   ZMB     5.754347e+05     1.219290e+09  358.140442
# 104  Lower middle income   ZWE     1.235213e+06     2.617295e+09  396.138824
#
#      HLO_average   total_pop  HLO_weighted_average          LAYS  \
# 0     355.407968  38928341.0            350.427762  9.324525e+06
# 1     413.097653   2837743.0            414.282878  5.450669e+04
# 2     387.426556  43851043.0            387.205977  2.887422e+06
# 3     387.426556  32866268.0            387.205977  7.757331e+06
# 4     413.097653  45376763.0            414.282878  2.645657e+06
# ..           ...         ...                   ...           ...
# 100   437.696625   3473727.0            437.696625  2.755612e+05
# 101   387.426556  97338583.0            387.205977  3.163306e+06
# 102   355.407968  29825968.0            350.427762  5.218727e+06
# 103   387.426556  18383956.0            387.205977  3.485003e+06
# 104   387.426556  14862927.0            387.205977  3.861205e+06
#
#      benefit_lives
# 0    144530.130727
# 1       844.853662
# 2     44755.033989
# 3    120238.637902
# 4     41007.681791
# ..             ...
# 100    4271.198517
# 101   49031.236095
# 102   80890.272688
# 103   54017.553411
# 104   59848.684307
#
# [105 rows x 65 columns]

# %%
def GDP_to_benefit_early_marriage(LAYS,income_group):
    X={
     'Low income':0.4946,
     'Lower middle income':0.7956,
     'Upper middle income':0.9372,
     'High income':0.9547   
    }
    Y={
     'Low income':0.7618,
     'Lower middle income':0.8923,
     'Upper middle income':0.9764,
     'High income':0.9738   
    }
    x = X[income_group]
    y = Y[income_group]
    
    b = LAYS
    w = b/2
    z = 0.075 * w * x * y 
    return z
f = GDP_to_benefit_early_marriage
#Public revenue generated
data_final['benefit_early_marriage'] = data_final.apply(lambda x: f(x['LAYS'],x['Income group']), axis=1) 

data_final.to_csv('return_UNICEF_benefit_with_all.csv')
data_final
# Out:
#      Unnamed: 0  Total_Never entered primary  Total_Dropped out of primary  \
# 0             0                    33.861341                      8.254577
# 1             1                     1.099108                      0.713800
# 2             2                     2.157483                      3.252027
# 3             3                     7.700000                      9.700000
# 4             4                     0.200000                      0.700000
# ..          ...                          ...                           ...
# 100          92                     1.400000                      1.300000
# 101          93                     1.700000                      1.600000
# 102          94                    10.800000                     15.400000
# 103          95                     3.524882                     16.126955
# 104          96                     0.336348                      6.855908
#
#      Total_Still attending primary  \
# 0                         3.415739
# 1                         0.099166
# 2                         0.397181
# 3                        22.800000
# 4                         1.500000
# ..                             ...
# 100                       0.800000
# 101                       0.100000
# 102                       5.900000
# 103                      13.010990
# 104                       0.422715
#
#      Total_Did not transition to lower secondary  \
# 0                                       3.786342
# 1                                       0.371935
# 2                                       0.444625
# 3                                       1.600000
# 4                                       1.400000
# ..                                           ...
# 100                                     4.800000
# 101                                     1.200000
# 102                                     6.100000
# 103                                     7.777071
# 104                                    14.874372
#
#      Total_Dropped out of lower secondary  \
# 0                                3.976628
# 1                                0.728686
# 2                               12.831457
# 3                                3.300000
# 4                                6.100000
# ..                                    ...
# 100                             10.600000
# 101                              8.400000
# 102                              5.600000
# 103                              4.604374
# 104                             17.744506
#
#      Total_Still attending lower secondary  \
# 0                                14.555927
# 1                                 0.048609
# 2                                26.817983
# 3                                39.500000
# 4                                29.300000
# ..                                     ...
# 100                              34.700000
# 101                               4.900000
# 102                              23.500000
# 103                              23.700449
# 104                              22.275173
#
#      Total_Did not transition to upper secondary  \
# 0                                       1.706868
# 1                                       9.871478
# 2                                       2.813620
# 3                                       0.800000
# 4                                       1.600000
# ..                                           ...
# 100                                     4.000000
# 101                                     7.900000
# 102                                     1.700000
# 103                                     5.466298
# 104                                    30.913427
#
#      Total_Transitioned to upper secondary  Total_population_agerange  ...  \
# 0                                30.442579                   2777.983  ...
# 1                                87.067217                    149.990  ...
# 2                                51.285623                   1792.845  ...
# 3                                14.700000                   2209.021  ...
# 4                                59.300000                   2131.984  ...
# ..                                     ...                        ...  ...
# 100                              42.400000                    145.968  ...
# 101                              74.300000                   3929.130  ...
# 102                              31.000000                   1959.731  ...
# 103                              25.788981                   1276.025  ...
# 104                               6.577552                   1332.280  ...
#
#      Code  benefit_poverty  benefit_revenue         HLO  HLO_average  \
# 0     AFG     2.535561e+05     6.325993e+08  354.758789   355.407968
# 1     ALB     4.300254e+04     1.242229e+08  434.127594   413.097653
# 2     DZA     1.682804e+06     3.565697e+09  374.089081   387.426556
# 3     AGO     1.833032e+06     3.884017e+09  325.965485   387.426556
# 4     ARG     2.940083e+06     8.493117e+09  408.172638   413.097653
# ..    ...              ...              ...         ...          ...
# 100   URY     2.221503e+05     1.773184e+09  437.696625   437.696625
# 101   VNM     1.402181e+06     2.971084e+09  519.100281   387.426556
# 102   YEM     3.978476e+05     9.925934e+08  321.327026   355.407968
# 103   ZMB     5.754347e+05     1.219290e+09  358.140442   387.426556
# 104   ZWE     1.235213e+06     2.617295e+09  396.138824   387.426556
#
#       total_pop  HLO_weighted_average          LAYS  benefit_lives  \
# 0    38928341.0            350.427762  9.324525e+06  144530.130727
# 1     2837743.0            414.282878  5.450669e+04     844.853662
# 2    43851043.0            387.205977  2.887422e+06   44755.033989
# 3    32866268.0            387.205977  7.757331e+06  120238.637902
# 4    45376763.0            414.282878  2.645657e+06   41007.681791
# ..          ...                   ...           ...            ...
# 100   3473727.0            437.696625  2.755612e+05    4271.198517
# 101  97338583.0            387.205977  3.163306e+06   49031.236095
# 102  29825968.0            350.427762  5.218727e+06   80890.272688
# 103  18383956.0            387.205977  3.485003e+06   54017.553411
# 104  14862927.0            387.205977  3.861205e+06   59848.684307
#
#      benefit_early_marriage
# 0             131750.734607
# 1               1870.428500
# 2              76868.273780
# 3             206513.898287
# 4              90787.245362
# ..                      ...
# 100             9606.960818
# 101            84212.794493
# 102            73737.931292
# 103            92776.961927
# 104           102792.125054
#
# [105 rows x 66 columns]
